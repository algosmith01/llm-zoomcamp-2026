# %%
from rag_helper import RagHelper

from openai import OpenAI
from dotenv import load_dotenv
load_dotenv()
openai_client = OpenAI()

# %%
## load the persistent index
import time
from sqlitesearch import TextSearchIndex

sqlite_index = TextSearchIndex(
    text_fields=["question", "section", "answer"],
    keyword_fields=["course"],
    db_path="faq.db"
)

# %%
#sqlite_index.search("how do I join the course?")

# %%
rag = RagHelper(index=sqlite_index,llm_client=openai_client)

# %%
rag.rag("how do i earn a certificate?")
# Out:
# 'You can earn a certificate by finishing the course with a live cohort and passing the capstone project.\n\nA few key points:\n- You do **not** get a certificate in self-paced mode.\n- You need to **submit your project while the course is still accepting submissions**.\n- You must also **peer-review 3 other capstone projects**.\n- Homework is **not required** for the certificate, but the capstone is.\n\nIf you want, I can also explain how to make sure your name appears correctly on the certificate.'

# %%
sqlite_index.count()
# Out:
# 79
